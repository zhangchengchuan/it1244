# %%
import sys
import librosa
import numpy as np
import matplotlib.pyplot as plt
import glob
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
import torchaudio.transforms as T

# Dataloader
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import KFold
import pandas as pd

# Models
# from '../models import CNN

from IPython.display import Audio

# %%
# Show all wav files
directory = '../Dataset/Audio Dataset/Cats and Dogs/data'
files = sorted(glob.glob(directory+'/*'))
print(files)
# Out:
# ['../Dataset/Audio Dataset/Cats and Dogs/data/cat_1.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_10.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_100.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_101.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_102.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_103.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_105.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_106.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_107.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_108.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_109.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_11.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_110.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_112.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_113.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_114.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_115.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_116.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_117.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_118.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_119.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_12.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_120.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_121.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_122.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_123.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_124.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_125.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_126.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_127.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_128.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_129.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_13.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_130.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_131.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_132.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_133.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_134.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_135.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_136.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_137.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_138.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_139.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_14.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_140.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_141.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_142.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_143.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_144.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_146.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_147.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_148.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_149.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_15.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_150.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_151.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_152.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_153.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_154.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_155.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_156.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_157.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_158.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_159.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_16.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_160.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_161.wav', '../Dataset/Audio Dataset/Cats and Dogs/data/cat_162.wa ...

# %% [markdown]
# ### Sample Cat Audio

# %%
print(files[0])
Audio(files[0])
# Out:
# ../Dataset/Audio Dataset/Cats and Dogs/data/cat_1.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Sample Dog Audio

# %%
print(files[200])
Audio(files[200])
# Out:
# ../Dataset/Audio Dataset/Cats and Dogs/data/dog_barking_3.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Preparing dataset

# %%
# Labelling the wav file and its classification
df = pd.DataFrame(columns=['idx', 'audio_file', 'classification'])
for idx, audio_file in enumerate(files):
    audio_path = audio_file.split('/')[-1]
    classification = audio_path.split('_')[0]
    row = pd.DataFrame([{"idx":idx, "audio_file": audio_file, "classification": 1 if classification=='dog' else 0}])
    df = pd.concat([df, row])

pd.set_option('display.max_rows', None)    # Show all rows
pd.set_option('display.max_columns', None)  
print(df)
# pd.reset_option()
# Out:
#    idx                                         audio_file classification
# 0    0  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    1  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    2  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    3  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    4  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    5  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    6  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    7  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    8  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0    9  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   10  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   11  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   12  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   13  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   14  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   15  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   16  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   17  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   18  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   19  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   20  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   21  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   22  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   23  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   24  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   25  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   26  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   27  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   28  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   29  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   30  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   31  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   32  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   33  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   34  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   35  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   36  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   37  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   38  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   39  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   40  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   41  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   42  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   43  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   44  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   45  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   46  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   47  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   48  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   49  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   50  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   51  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   52  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   53  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   54  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   55  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   56  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   57  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   58  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   59  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   60  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   61  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   62  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   63  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   64  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   65  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   66  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   67  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   68  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   69  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   70  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   71  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   72  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   73  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   74  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   75  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   76  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   77  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   78  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   79  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   80  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   81  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   82  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   83  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   84  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   85  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   86  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   87  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   88  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   89  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   90  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   91  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   92  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   93  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   94  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   95  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   96  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   97  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   98  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0   99  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  100  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  101  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  102  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  103  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  104  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  105  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  106  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  107  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  108  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  109  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  110  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  111  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  112  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  113  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  114  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  115  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  116  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  117  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  118  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  119  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  120  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  121  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  122  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  123  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  124  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  125  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  126  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  127  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  128  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  129  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  130  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  131  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  132  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  133  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  134  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  135  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  136  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  137  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  138  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  139  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  140  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  141  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  142  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  143  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  144  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  145  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  146  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  147  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  148  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  149  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  150  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  151  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  152  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  153  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  154  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  155  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  156  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  157  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  158  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  159  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  160  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  161  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  162  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  163  ../Dataset/Audio Dataset/Cats and Dogs/data/ca...              0
# 0  164  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  165  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  166  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  167  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  168  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  169  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  170  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  171  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  172  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  173  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  174  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  175  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  176  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  177  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  178  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  179  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  180  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  181  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  182  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  183  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  184  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  185  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  186  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  187  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  188  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  189  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  190  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  191  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  192  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  193  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  194  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  195  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  196  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  197  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  198  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  199  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  200  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  201  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  202  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  203  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  204  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  205  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  206  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  207  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  208  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  209  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  210  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  211  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  212  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  213  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  214  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  215  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  216  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  217  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  218  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  219  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  220  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  221  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  222  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  223  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  224  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  225  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  226  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  227  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  228  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  229  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  230  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  231  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  232  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  233  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  234  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  235  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  236  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  237  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  238  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  239  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  240  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  241  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  242  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  243  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  244  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  245  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  246  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  247  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  248  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  249  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  250  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  251  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  252  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  253  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  254  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  255  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  256  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  257  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  258  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  259  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  260  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  261  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  262  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  263  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  264  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  265  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  266  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  267  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  268  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  269  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  270  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  271  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  272  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  273  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  274  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  275  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1
# 0  276  ../Dataset/Audio Dataset/Cats and Dogs/data/do...              1

# %% [markdown]
# ### Creating custom dataloader class

# %%
class CatsAndDogsDataset(Dataset):
    def __init__(self, target_length, n_fft, hop, dataframe):
        self.df = dataframe
        self.n_fft = n_fft
        self.hop = hop
        self.target_length = target_length
 
    def __getitem__(self, index):
        audio_path = self.df.iloc[index]['audio_file']
        signal, sr = torchaudio.load(audio_path)
        modified_signal = self._process_signal(signal)
        classification = self.df.iloc[index]['classification']
        return modified_signal, classification
    
    def __len__(self):
        return len(self.df)
    
    def _process_signal(self, signal):
        # Right pad the audio files that are shorter than target, cut if longer.
        if len(signal) > self.target_length:
            print(signal.shape)
            signal = signal[:, :self.target_length]
            print(signal.shape)
        elif len(signal) < self.target_length:
            signal = F.pad(signal, [0, self.target_length-signal.shape[1]])
            
        spectrogram = T.Spectrogram(n_fft=self.n_fft, hop_length=self.hop)(signal)
        return spectrogram

# %% [markdown]
# ### Train and Test functions

# %%
def train_model(model, lr, epochs, dataset, dataframe, loss_fn, batch_size):
    # Optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr)
    # train_loader = DataLoader(dataset, batch_size=batch_size)
    kf = KFold(n_splits=2, shuffle=True, random_state=10)

    for fold, (train_idx, val_idx) in enumerate(kf.split(dataframe)):
        print(f"Fold: {fold}")
        train_subset = Subset(dataset, train_idx)
        # val_subset = Subset(dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        # val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Training loop for this fold
        losses = []
        for epoch in range(epochs):
            model.train()
            for mfccs, labels in train_loader:
                optimizer.zero_grad()
                output = model(mfccs)
                loss = loss_fn(output, labels)
                loss.backward()
                optimizer.step()
            print(loss.item())
            losses.append(loss.item())
        
        plt.figure(figsize=(16,8))
        plt.plot(np.arange(epochs), losses)
        plt.title(f'Training Loss over epochs for fold {fold}')
        plt.xlabel('Loss')
        plt.ylabel('Epochs')
        plt.show()

# %% [markdown]
# ### Trying out different models

# %%
# Baseline CNN
class CNN(nn.Module):
    def __init__(self, n_fft, hop):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=16,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(
                in_channels=64,
                out_channels=128,
                kernel_size=3,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(116480, 2)
        self.softmax = nn.Softmax()

    def forward(self, input):
        # print(f"Input shape: {input.shape}")
        x = self.conv1(input)
        # print(f"After conv1: {x.shape}")
        x = self.conv2(x)
        # print(f"After conv2: {x.shape}")
        x = self.conv3(x)
        # print(f"After conv3: {x.shape}")
        x = self.conv4(x)
        # print(f"After conv4: {x.shape}")
        x = self.flatten(x)
        # print(f"After flatten: {x.shape}")
        logits = self.linear(x)
        # print(f"After linear: {x.shape}")
        predictions = self.softmax(logits)
        # print(f"After softmax: {x.shape}")
        return predictions

# %%
# Hyperparameters
target_length = 200000  # Check data_exploration.ipynb. average length is approximately this number
target_sr = 16000  # All audio are at 16K Hz
n_fft = 2048 # Power 2
hop = 1024 # Typically 0.5/0.75 of n_fft
train_dataframe = df.sample(frac=0.8, random_state=42) # From above
test_dataframe = df.loc[~df.idx.isin(train_dataframe.idx)]
# train_dataframe = dataframe[]
lr = 0.001
epochs = 50
batch_size = 32

# # Create dataloader class
train_dataset = CatsAndDogsDataset(target_length=target_length, n_fft=n_fft, hop=hop, dataframe=train_dataframe)
test_dataset = CatsAndDogsDataset(target_length=target_length, n_fft=n_fft, hop=hop, dataframe=test_dataframe)

# Create model
cnn_dict = torch.load('../models/CNN/cnn.pth')
cnn = CNN(n_fft=n_fft, hop=hop)
cnn.load_state_dict(cnn_dict)
# Out:
# <All keys matched successfully>

# %%
def test_model(model, test_dataframe):
    labels = {
        0: "Cat",
        1: "Dog"
    }
    model.eval()
    with torch.no_grad():
        correct = 0
        for idx in range(len(test_dataframe)):
            row = test_dataframe.iloc[idx]
            audio_path = row['audio_file']
            signal, sr = torchaudio.load(audio_path)
            if len(signal) > 200000:
                print(signal.shape)
                signal = signal[:, :200000]
                print(signal.shape)
            elif len(signal) < 200000:
                signal = F.pad(signal, [0, 200000-signal.shape[1]])
            
            spectrogram = T.Spectrogram(n_fft=2048, hop_length=1024)(signal)
            classification = row['classification']
            prediction = model(spectrogram.unsqueeze(0))
            if labels[torch.argmax(prediction,dim=1).item()] == labels[classification]:
                correct += 1
            print(f"Prediction: {labels[torch.argmax(prediction,dim=1).item()]}, Actual: {labels[classification]}")

    print(len(train_dataframe))
    print(f"Total accuracy: {correct/len(test_dataframe)}")
            


test_model(cnn, test_dataframe)
# Out:
# /var/folders/jc/fc0psy1n4wb4604hfb_bgb4m0000gn/T/ipykernel_91115/473494261.py:67: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   predictions = self.softmax(logits)
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Cat, Actual: Cat
# Prediction: Dog, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# Prediction: Cat, Actual: Dog
# 222
# Total accuracy: 0.6181818181818182

# %%
# len(train_dataframe)
# len(df)
len(test_dataframe)
# Out:
# 55
